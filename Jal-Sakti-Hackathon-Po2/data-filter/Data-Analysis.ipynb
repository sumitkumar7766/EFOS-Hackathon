# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Column-Correct-Data/new_2024-2025.csv')

# %%
df.count()
# Out:
# S.No                                                                                     736
# STATE                                                                                    735
# DISTRICT                                                                                 735
# ASSESSMENT UNIT                                                                            0
# Rainfall (mm)_C                                                                          729
#                                                                                         ...
# In-Storage Semi Confined Ground Water Resources (ham)_Other Parameters Present_Saline      7
# Total Semi-Confined Ground Water Resources (ham)_Other Parameters Present_Fresh            4
# Total Semi-Confined Ground Water Resources (ham)_Other Parameters Present_Saline           0
# Total Ground Water Availability in the area (ham)_Other Parameters Present_Fresh         729
# ...

# %%
df.head()
# Out:
#   S.No                        STATE               DISTRICT  ASSESSMENT UNIT  \
# 0    1  ANDAMAN AND NICOBAR ISLANDS          N & M ANDAMAN              NaN
# 1    2  ANDAMAN AND NICOBAR ISLANDS                NICOBAR              NaN
# 2    3  ANDAMAN AND NICOBAR ISLANDS          SOUTH ANDAMAN              NaN
# 3    4               ANDHRA PRADESH  Alluri Sitharama Raju              NaN
# 4    5               ANDHRA PRADESH             Anakapalli              NaN
#
#    Rainfall (mm)_C  Rainfall (mm)_NC  Rainfall (mm)_PQ  Rainfall (mm)_Total  \
# 0         0.000000       3015.700000               0.0          3015.700000
# 1         0.000000       2805.200000            2805.2          2805.200000
# 2         0.000000       3015.700000               0.0          3015.700000
# 3         0.000000       1257.832755               0.0          1257.832755
# 4      1205.747378       1176.354436               0.0          1182.552833
#
# ...

# %%
drop_col = ["ASSESSMENT UNIT", "S.No"]
df = df.drop(drop_col, axis=1)

# %%
df.head()
# Out:
#                          STATE               DISTRICT  Rainfall (mm)_C  \
# 0  ANDAMAN AND NICOBAR ISLANDS          N & M ANDAMAN         0.000000
# 1  ANDAMAN AND NICOBAR ISLANDS                NICOBAR         0.000000
# 2  ANDAMAN AND NICOBAR ISLANDS          SOUTH ANDAMAN         0.000000
# 3               ANDHRA PRADESH  Alluri Sitharama Raju         0.000000
# 4               ANDHRA PRADESH             Anakapalli      1205.747378
#
#    Rainfall (mm)_NC  Rainfall (mm)_PQ  Rainfall (mm)_Total  \
# 0       3015.700000               0.0          3015.700000
# 1       2805.200000            2805.2          2805.200000
# 2       3015.700000               0.0          3015.700000
# 3       1257.832755               0.0          1257.832755
# 4       1176.354436               0.0          1182.552833
#
#    Total Geographical Area (ha)_Recharge Worthy Area (ha)_C  \
# 0                                                0.0
# 1                                                0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Columns: 151 entries, STATE to Total Ground Water Availability in the area (ham)_Other Parameters Present_Saline
# dtypes: float64(146), object(5)
# memory usage: 868.4+ KB

# %%
df.describe()
# Out:
#        Rainfall (mm)_C  Rainfall (mm)_NC  Rainfall (mm)_PQ  \
# count       729.000000        729.000000        729.000000
# mean        647.661149       1062.273500         95.309171
# std         622.103786        897.110366        313.351556
# min           0.000000          0.000000          0.000000
# 25%           0.000000        325.850911          0.000000
# 50%         711.117619        999.600000          0.000000
# 75%        1075.500000       1425.976376          0.000000
# max        3583.672339       4419.644794       2805.200000
#
#        Rainfall (mm)_Total  \
# count           729.000000
# mean           1252.232368
# std             745.162140
# min               0.000000
# 25%             777.222719
# 50%            1074.100000
# 75%            1445.098624
# max            4419.644794
#
#        Total Geographical Area (ha)_Recharge Worthy Area (ha)_C  \
# count                                       7.360000e+02
# ...
